# %% [markdown]
# ### PROJECT
# ### CONSUMER FINANCIAL COMPLAINTS AND RESPONSE ANALYTICS

# %% [markdown]
# #### PROBLEM STATEMENT
# ##### Financial institutions are required to respond to consumer complaints in a timely and effective manner to comply with regulatory standards set by the Consumer Financial Protection Bureau (CFPB).
# ##### The objective of this project is to analyze consumer financial complaints data to:
# ##### 1. Monitor complaint volume and trends over time
# ##### 2. Evaluate company responsiveness and resolution quality
# ##### 3. Identify high-risk financial products and issue types
# #### The insights from this analysis can help financial institutions and fintech companies improve operational performance, reduce regulatory risk, and enhance customer experience.

# %% [markdown]
# #### This notebook contains:
# ##### 1. Importing the dataset and the required libraries, understading what each column of the dataset means, doing all the basic checks like checking for duplicates, datatypes od columns, missing values, etc.
# ##### 2. Data cleaning
# ##### 3. Feature Engineering
# ##### 4. Saving the dataset

# %%
# Importing the required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Ignoring harmless warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing the raw dataset for analysis
df = pd.read_csv('../data/raw/raw_data.csv')
df.head()
# Out:
#   date_received          product        subproduct  \
# 0    2021-03-13  Debt collection        Other debt
# 1    2019-12-31  Debt collection        Other debt
# 2    2021-03-01  Debt collection  Credit card debt
# 3    2021-08-16  Debt collection     I do not know
# 4    2019-11-21  Debt collection        Other debt
#
#                                issue           subissue company_name state  \
# 0  Attempts to collect debt not owed      Debt was paid          ERC    IA
# 1  Attempts to collect debt not owed  Debt is not yours          ERC    CA
# 2  Attempts to collect debt not owed  Debt is not yours          ERC    NY
# 3  Attempts to collect debt not owed  Debt is not yours          ERC    NY
# 4  Attempts to collect debt not owed  Debt is not yours          ERC    PA
#
#   company_response_to_consumer  timely_response  consumer_disputed
# 0      Closed with explanation             True                NaN
# 1      Closed with explanation             True                NaN
# 2      Closed with explanation             True                NaN
# 3      Closed with explanation             True                NaN
# 4      Closed with explanation             True                NaN

# %% [markdown]
# #### Understanding the meaning of each column:
# ##### date_received: The date on which the consumer complaint was received by the CFPB.
# ##### product: The financial product or service against which the complaint is filed.
# ##### subproduct: Specific subproduct of the product category.
# ##### issue: The complaint that has been filed against the project.
# ##### subissue: Detailed complaint.
# ##### company_name: The name of the company that owns the financial product or service.
# ##### state: The state to which the company belongs to.
# ##### company_response_to_consumer: The company's response to the consumer's complaint.
# ##### timely_response: Whether the company has responded to the complaint in the given time.
# ##### consumer_disputed: Whether the consumer disagreed with the company's response.

# %% [markdown]
# #### UNDERSTANDING THE DATA - DOING BASIC CHECKS

# %%
# Checking the number of rows and columns in the dataset:

print(f"The number of rows in the dataset is {df.shape[0]} and the number of columns is {df.shape[1]}.")
# Out:
# The number of rows in the dataset is 2262724 and the number of columns is 10.

# %%
# Checking for duplicates in the dataset:
print(f"The number of duplicate rows in the dataset is {df.duplicated().sum()}.")
print(f"The percentage of duplicate rows in the dataset is {df.duplicated().mean()*100} %.")
# Out:
# The number of duplicate rows in the dataset is 831228.
# The percentage of duplicate rows in the dataset is 36.73572207657673 %.

# %%
# Removing duplicate rows of the dataset:
df = df.drop_duplicates()

# %%
# Checking if the duplicates are removed successfully
print(f"After removing duplicates, the number of rows in the dataset is {df.shape[0]}.")
print(f"The number of duplicate rows in the dataset is now {df.duplicated().sum()}.")
# Out:
# After removing duplicates, the number of rows in the dataset is 1431496.
# The number of duplicate rows in the dataset is now 0.

# %%
# Checking the datatype of each column:

df.dtypes
# Out:
# date_received                    object
# product                          object
# subproduct                       object
# issue                            object
# subissue                         object
# company_name                     object
# state                            object
# company_response_to_consumer     object
# timely_response                    bool
# consumer_disputed               float64
# dtype: object

# %% [markdown]
# ##### The datatype of date_received is object, it has to be converted to datetime.

# %%
# Checking for the percentage of missing values in each column

df.isnull().mean()*100
# Out:
# date_received                     0.000000
# product                           0.000000
# subproduct                        0.007335
# issue                             0.000000
# subissue                         12.149458
# company_name                      0.000000
# state                             1.510238
# company_response_to_consumer      0.000210
# timely_response                   0.000000
# consumer_disputed               100.000000
# dtype: float64

# %%
# Checking for the number of missing values in each column

df.isnull().sum()
# Out:
# date_received                         0
# product                               0
# subproduct                          105
# issue                                 0
# subissue                         173919
# company_name                          0
# state                             21619
# company_response_to_consumer          3
# timely_response                       0
# consumer_disputed               1431496
# dtype: int64

# %% [markdown]
# ##### The columns subproduct and company_response_to_consumer have very few missing values. So those particular rows can be dropped. The missing values in the columns state and subissue can be filled by their mode values. The column consumer_disputed has all missing values, so the entire column needs to be dropped.

# %%
# Checking the number of unique values in each column

df.nunique()
# Out:
# date_received                   1542
# product                            9
# subproduct                        48
# issue                             81
# subissue                         166
# company_name                    5246
# state                             61
# company_response_to_consumer       5
# timely_response                    2
# consumer_disputed                  0
# dtype: int64

# %% [markdown]
# ##### Except for product, company_response_to_consumer, and timely_response, all other columns have high cardinality.

# %%
# Finding the unique values in the columns 'product', 'company_response_to_consumer', and 'timely_response':
print(f"The unique values in the 'product' column are: {df['product'].unique()}")
print(f"The unique values in the 'company_response_to_consumer' column are: {df['company_response_to_consumer'].unique()}")
print(f"The unique values in the 'timely_response' column are: {df['timely_response'].unique()}")
# Out:
# The unique values in the 'product' column are: ['Debt collection'
#  'Credit reporting, credit repair services, or other personal consumer reports'
#  'Money transfer, virtual currency, or money service' 'Student loan'
#  'Mortgage' 'Checking or savings account' 'Credit card or prepaid card'
#  'Payday loan, title loan, or personal loan' 'Vehicle loan or lease']
# The unique values in the 'company_response_to_consumer' column are: ['Closed with explanation' 'In progress' 'Closed with monetary relief'
#  'Closed with non-monetary relief' 'Untimely response' nan]
# The unique values in the 'timely_response' column are: [ True False]

# %% [markdown]
# #### DATA CLEANING
# ##### CONVERTING THE DTYPE OF THE 'date_received' COLUMN TO DATETIME:

# %%
df["date_received"] = pd.to_datetime(df["date_received"])

# Checking if the conversion is done correctly:
df.dtypes
# Out:
# date_received                   datetime64[ns]
# product                                 object
# subproduct                              object
# issue                                   object
# subissue                                object
# company_name                            object
# state                                   object
# company_response_to_consumer            object
# timely_response                           bool
# consumer_disputed                      float64
# dtype: object

# %% [markdown]
# ##### HANDLING MISSING VALUES

# %%
# Dropping the column "consumer_disputed", since all of its values were missing:

df.drop("consumer_disputed", axis=1, inplace=True)

# %%
# Dropping the rows with missing values in the 'company_response_to_customer' and 'subproduct'columns:
df = df.dropna(subset=['company_response_to_consumer', 'subproduct'])

# Checking if they have been removed successfully:
df.isnull().sum()
# Out:
# date_received                        0
# product                              0
# subproduct                           0
# issue                                0
# subissue                        173915
# company_name                         0
# state                            21614
# company_response_to_consumer         0
# timely_response                      0
# dtype: int64

# %%
# The missing values in the 'state' can be imputed using the mode of the column.
# Finding the mode of the 'state' column:
state_mode = df['state'].mode()[0]
state_mode
# Out:
# 'CA'

# %%
# Filling the missing values in the 'state' column with the mode:
df['state'] = df['state'].fillna(state_mode)

# Checking if the missing values in the 'state' column have been filled successfully:
df.isnull().sum()
# Out:
# date_received                        0
# product                              0
# subproduct                           0
# issue                                0
# subissue                        173915
# company_name                         0
# state                                0
# company_response_to_consumer         0
# timely_response                      0
# dtype: int64

# %%
# The missing values in the 'subissue' column needs to be handled using a different strategy.
# Each subissue is a subcategory of a broader category 'issue'. So, instead of blindly filling the missing values
# using the mode of the entire 'subissue' column, we can find the mode of 'subissue' for each category in the 'issue' column.
# First finding the rows with missing values in the 'subissue' column:
missing_subissue = df[df['subissue'].isnull()]
missing_subissue
# Out:
#         date_received                                            product  \
# 40         2022-01-07  Money transfer, virtual currency, or money ser...
# 75         2021-11-05                                           Mortgage
# 76         2020-03-11                                           Mortgage
# 77         2021-06-16                                           Mortgage
# 78         2020-12-01                                           Mortgage
# ...               ...                                                ...
# 2262667    2019-11-20                                           Mortgage
# 2262690    2021-05-17                                           Mortgage
# 2262713    2019-10-28                                           Mortgage
# 2262714    2022-02-22                                           Mortgage
# 2262715    2019-10-31                                           Mortgage
#
#                                          subproduct  \
# 40                         Mobile or digital wallet
# 75                       Conventional home mortgage
# 76                       Conventional home mortgage
# 77                           Other type of mortgage
# 78       Home equity loan or line of credit (HELOC)
# ...                                             ...
# 2262667                  Conventional home mortgage
# 2262690                  Conventional home mortgage
# 2262713                  Conventional home mortgage
# 2262714                  Conventional home mortgage
# 2262715                  Conventional home mortgage
#
#                                                      issue subissue  \
# 40       Managing, opening, or closing your mobile wall...      NaN
# 75                                   Closing on a mortgage      NaN
# 76                          Trouble during payment process      NaN
# 77                          Trouble during payment process      NaN
# 78       Applying for a mortgage or refinancing an exis...      NaN
# ...                                                    ...      ...
# 2262667                     Trouble during payment process      NaN
# 2262690  Applying for a mortgage or refinancing an exis...      NaN
# 2262713                         Struggling to pay mortgage      NaN
# 2262714  Applying for a mortgage or refinancing an exis...      NaN
# 2262715                     Trouble during payment process      NaN
#
#                                               company_name state  \
# 40                                                    Abra    CA
# 75                                                 KEYCORP    OH
# 76                                                 KEYCORP    CT
# 77                                                 KEYCORP    MA
# 78                                                 KEYCORP    NY
# ...                                                    ...   ...
# 2262667         PEOPLE'S UNITED BANK, NATIONAL ASSOCIATION    CT
# 2262690  CALCON MUTUAL MORTGAGE LLC DBA ONETRUST HOME L...    NY
# 2262713  Community Loan Servicing, LLC (formerly known ...    TN
# 2262714  Community Loan Servicing, LLC (formerly known ...    OK
# 2262715  Community Loan Servicing, LLC (formerly known ...    NC
#
#             company_response_to_consumer  timely_response
# 40               Closed with explanation             True
# 75               Closed with explanation             True
# 76               Closed with explanation             True
# 77               Closed with explanation             True
# 78               Closed with explanation             True
# ...                                  ...              ...
# 2262667          Closed with explanation             True
# 2262690  Closed with non-monetary relief            False
# 2262713          Closed with explanation             True
# 2262714          Closed with explanation             True
# 2262715          Closed with explanation             True
#
# [173915 rows x 9 columns]

# %%
# Finding the categories in the 'issue' column in the above dataset 'missing_subissue':
missing_subissue['issue'].value_counts()
# Out:
# issue
# Trouble during payment process                                                      47723
# Struggling to pay mortgage                                                          23859
# Fraud or scam                                                                       16371
# Applying for a mortgage or refinancing an existing mortgage                         15646
# Closing on a mortgage                                                                9351
# Problem with fraud alerts or security freezes                                        9161
# Other transaction problem                                                            6881
# Managing, opening, or closing your mobile wallet account                             4520
# Charged fees or interest you didn't expect                                           4427
# Unauthorized transactions or other transaction problem                               4030
# Money was not available when promised                                                3977
# Unexpected or other fees                                                             3328
# Problem when making payments                                                         2681
# Incorrect information on your report                                                 2563
# Struggling to pay your loan                                                          2503
# Problem with the payoff process at the end of the loan                               1975
# Other service problem                                                                1616
# Getting the loan                                                                     1606
# Confusing or missing disclosures                                                     1471
# Problem with customer service                                                        1455
# Getting a line of credit                                                             1331
# Confusing or misleading advertising or marketing                                      909
# Problem with a credit reporting company's investigation into an existing problem      848
# Problem with additional add-on products or services                                   748
# Wrong amount charged or received                                                      602
# Received a loan you didn't apply for                                                  558
# Can't contact lender or servicer                                                      489
# Problem adding money                                                                  484
# Improper use of your report                                                           340
# Loan payment wasn't credited to your account                                          297
# Lost or stolen check                                                                  290
# Can't stop withdrawals from your bank account                                         283
# Money was taken from your bank account on the wrong day or for the wrong amount       231
# Vehicle was repossessed or sold the vehicle                                           201
# Was approved for a loan, but didn't receive the money                                 186
# Lost or stolen money order                                                            179
# Excessive fees                                                                        152
# Credit limit changed                                                                  144
# Problem with cash advance                                                             111
# Credit monitoring or identity theft protection services                                72
# Overdraft, savings, or rewards features                                                69
# Vehicle was damaged or destroyed the vehicle                                           65
# Unable to get your credit report or credit score                                       62
# Incorrect exchange rate                                                                52
# Was approved for a loan, but didn't receive money                                      41
# Problem with credit report or credit score                                              9
# Managing an account                                                                     5
# Getting a loan                                                                          5
# Property was sold                                                                       4
# Property was damaged or destroyed property                                              3
# Communication tactics                                                                   1
# Name: count, dtype: int64

# %%
# Finding the mode value of each category in the 'subissue' column corresponding to each category in the 'issue' column:

for cat in missing_subissue["issue"].unique():
    print(df.groupby("issue").agg({'subissue': pd.Series.mode}).loc[cat])
# Out:
# subissue    []
# Name: Managing, opening, or closing your mobile wallet account, dtype: object
# subissue    []
# Name: Closing on a mortgage, dtype: object
# subissue    []
# Name: Trouble during payment process, dtype: object
# subissue    []
# Name: Applying for a mortgage or refinancing an existing mortgage, dtype: object
# subissue    []
# Name: Unexpected or other fees, dtype: object
# subissue    []
# Name: Charged fees or interest you didn't expect, dtype: object
# subissue    []
# Name: Getting the loan, dtype: object
# subissue    []
# Name: Problem with fraud alerts or security freezes, dtype: object
# subissue    []
# Name: Struggling to pay mortgage, dtype: object
# subissue    []
# Name: Fraud or scam, dtype: object
# subissue    []
# Name: Unauthorized transactions or other transaction problem, dtype: object
# subissue    []
# Name: Problem with customer service, dtype: object
# subissue    []
# Name: Other transaction problem, dtype: object
# subissue    []
# Name: Was approved for a loan, but didn't receive the money, dtype: object
# subissue    []
# Name: Money was not available when promised, dtype: object
# subissue    []
# Name: Other service problem, dtype: object
# subissue    []
# Name: Credit limit changed, dtype: object
# subissue    []
# Name: Confusing or misleading advertising or marketing, dtype: object
# subissue    []
# Name: Confusing or missing disclosures, dtype: object
# subissue    Reporting company used your report improperly
# Name: Improper use of your report, dtype: object
# subissue    []
# Name: Can't stop withdrawals from your bank account, dtype: object
# subissue    []
# Name: Loan payment wasn't credited to your account, dtype: object
# subissue    []
# Name: Excessive fees, dtype: object
# subissue    Their investigation did not fix an error on yo...
# Name: Problem with a credit reporting company's investigation into an existing problem, dtype: object
# subissue    Denied request to lower payments
# Name: Struggling to pay your loan, dtype: object
# subissue    []
# Name: Can't contact lender or servicer, dtype: object
# subissue    Problem during payment process
# Name: Problem when making payments, dtype: object
# subissue    []
# Name: Problem with the payoff process at the end of the loan, dtype: object
# subissue    Information belongs to someone else
# Name: Incorrect information on your report, dtype: object
# subissue    []
# Name: Problem adding money, dtype: object
# subissue    []
# Name: Received a loan you didn't apply for, dtype: object
# subissue    []
# Name: Getting a line of credit, dtype: object
# subissue    []
# Name: Lost or stolen check, dtype: object
# subissue    []
# Name: Lost or stolen money order, dtype: object
# subissue    []
# Name: Problem with additional add-on products or services, dtype: object
# subissue    []
# Name: Money was taken from your bank account on the wrong day or for the wrong amount, dtype: object
# subissue    []
# Name: Overdraft, savings, or rewards features, dtype: object
# subissue    []
# Name: Vehicle was repossessed or sold the vehicle, dtype: object
# subissue    []
# Name: Wrong amount charged or received, dtype: object
# subissue    []
# Name: Vehicle was damaged or destroyed the vehicle, dtype: object
# subissue    []
# Name: Problem with cash advance, dtype: object
# subissue    Billing dispute for services
# Name: Credit monitoring or identity theft protection services, dtype: object
# subissue    []
# Name: Was approved for a loan, but didn't receive money, dtype: object
# subissue    []
# Name: Property was sold, dtype: object
# subissue    []
# Name: Incorrect exchange rate, dtype: object
# subissue    Other problem getting your report or credit score
# Name: Unable to get your credit report or credit score, dtype: object
# subissue    []
# Name: Property was damaged or destroyed property, dtype: object
# subissue    Incorrect information on your report
# Name: Problem with credit report or credit score, dtype: object
# subissue    Deposits and withdrawals
# Name: Managing an account, dtype: object
# subissue    Frequent or repeated calls
# Name: Communication tactics, dtype: object
# subissue    Fraudulent loan
# Name: Getting a loan, dtype: object

# %% [markdown]
# ##### From the above series, it is observed that the mode of the most of the subissue category is nan. So, we may have to impute these missing values with the mode of the entire column. But it may introduce wrong values and reduce the data quality. So, it is better to drop the entire 'subissue' column, since we already have the 'issue' column which can be used for analysis.

# %%
# Dropping the subissue column:
df = df.drop("subissue", axis=1)
df.head()
# Out:
#   date_received          product        subproduct  \
# 0    2021-03-13  Debt collection        Other debt
# 1    2019-12-31  Debt collection        Other debt
# 2    2021-03-01  Debt collection  Credit card debt
# 3    2021-08-16  Debt collection     I do not know
# 4    2019-11-21  Debt collection        Other debt
#
#                                issue company_name state  \
# 0  Attempts to collect debt not owed          ERC    IA
# 1  Attempts to collect debt not owed          ERC    CA
# 2  Attempts to collect debt not owed          ERC    NY
# 3  Attempts to collect debt not owed          ERC    NY
# 4  Attempts to collect debt not owed          ERC    PA
#
#   company_response_to_consumer  timely_response
# 0      Closed with explanation             True
# 1      Closed with explanation             True
# 2      Closed with explanation             True
# 3      Closed with explanation             True
# 4      Closed with explanation             True

# %% [markdown]
# ##### FEATURE ENGINEERING
# ##### Creating new features "month_and_year" denoting the month and year in which the complaint was received by the CFPB, and "year" denoting the year in which the complaint was received.

# %%
df['month_and_year'] = df['date_received'].dt.to_period('M')

# %%
df.head()
# Out:
#   date_received          product        subproduct  \
# 0    2021-03-13  Debt collection        Other debt
# 1    2019-12-31  Debt collection        Other debt
# 2    2021-03-01  Debt collection  Credit card debt
# 3    2021-08-16  Debt collection     I do not know
# 4    2019-11-21  Debt collection        Other debt
#
#                                issue company_name state  \
# 0  Attempts to collect debt not owed          ERC    IA
# 1  Attempts to collect debt not owed          ERC    CA
# 2  Attempts to collect debt not owed          ERC    NY
# 3  Attempts to collect debt not owed          ERC    NY
# 4  Attempts to collect debt not owed          ERC    PA
#
#   company_response_to_consumer  timely_response month_and_year
# 0      Closed with explanation             True        2021-03
# 1      Closed with explanation             True        2019-12
# 2      Closed with explanation             True        2021-03
# 3      Closed with explanation             True        2021-08
# 4      Closed with explanation             True        2019-11

# %%
df["year_received"] = df['date_received'].dt.year

# %%
# Since 'year' and 'month_and_year' columns are created from the 'date_received' column, we can drop the 'date_received' column now.
df = df.drop("date_received", axis=1)

# %%
# Checking the final dataset:

df.head()
# Out:
#            product        subproduct                              issue  \
# 0  Debt collection        Other debt  Attempts to collect debt not owed
# 1  Debt collection        Other debt  Attempts to collect debt not owed
# 2  Debt collection  Credit card debt  Attempts to collect debt not owed
# 3  Debt collection     I do not know  Attempts to collect debt not owed
# 4  Debt collection        Other debt  Attempts to collect debt not owed
#
#   company_name state company_response_to_consumer  timely_response  \
# 0          ERC    IA      Closed with explanation             True
# 1          ERC    CA      Closed with explanation             True
# 2          ERC    NY      Closed with explanation             True
# 3          ERC    NY      Closed with explanation             True
# 4          ERC    PA      Closed with explanation             True
#
#   month_and_year  year_received
# 0        2021-03           2021
# 1        2019-12           2019
# 2        2021-03           2021
# 3        2021-08           2021
# 4        2019-11           2019

# %%
# Checking for missing values and dtypes once again:
df.isnull().sum(), df.dtypes
# Out:
# (product                         0
#  subproduct                      0
#  issue                           0
#  company_name                    0
#  state                           0
#  company_response_to_consumer    0
#  timely_response                 0
#  month_and_year                  0
#  year_received                   0
#  dtype: int64,
#  product                            object
#  subproduct                         object
#  issue                              object
#  company_name                       object
#  state                              object
#  company_response_to_consumer       object
#  timely_response                      bool
#  month_and_year                  period[M]
#  year_received                       int32
#  dtype: object)

# %% [markdown]
# ##### SAVING THE CLEANED DATASET

# %%
# Saving the cleaned dataset to the processed folder in the data directory:
df.to_csv('../data/processed/cleaned_data.csv', index=False)
